# %%
from manim import *
# Out:
# Manim Community v0.16.0.post0

# %%
class CreateCircle(Scene):
    def construct(self):
        circle = Circle()  # create a circle
        circle.set_fill(PINK, opacity=0.5)  # set the color and transparency
        self.play(Create(circle))  # show the circle on screen

        #mob = Matrix([[9, 3], [1, 5]]) 
        #bra = mob.get_brackets() 
        #bra.set_color(YELLOW)

# %%
# %%manim -q CreateCircle
# Out:
# UsageError: %%manim is a cell magic, but the cell body is empty. Did you mean the line magic %manim (single %)?

# %%
# %manim -s CircleToSquare

class CircleToSquare(Scene):
    def construct(self):
        blue_circle = Circle(color=BLUE, fill_opacity=0.5)
        green_square = Square(color=GREEN, fill_opacity=0.8)
        self.play(Create(blue_circle))
        self.wait()
        
        self.play(Transform(blue_circle, green_square))
        self.wait()
# Out:
# [10/30/22 18:31:17] INFO                                                                   ]8;id=275444;file:///home/pesho/anaconda3/lib/python3.9/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=767325;file:///home/pesho/anaconda3/lib/python3.9/site-packages/manim/scene/scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              '/home/pesho/work/manim/media/images/manim/CircleToSquare_Man
#                              imCE_v0.16.0.post0.png'
#                     INFO     Rendered CircleToSquare                                                   ]8;id=196272;file:///home/pesho/anaconda3/lib/python3.9/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=373733;file:///home/pesho/anaconda3/lib/python3.9/site-packages/manim/scene/scene.py#240\240]8;;\
#                              Played 4 animations
